# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
x = torch.randn((2,3))
x
# Out:
# tensor([[ 0.5891, -1.5730, -0.2003],
#         [-1.1114,  0.6692,  0.0976]])

# %%
# Out:
# -0.4161468365471424
