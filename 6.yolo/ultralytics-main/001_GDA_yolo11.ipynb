# %%
from ultralytics import YOLO
import torch

# %%
if __name__ == '__main__':
    yolo = YOLO('yolo11n-seg.pt')
    yolo.train(
        data=r'E:\\mastercode\\6.yolo\\ultralytics-main\\voc20007_seg_yolov8.yaml',
        project=r'E:/mastercode/6.yolo/runs/segment',
        epochs=150,
        imgsz=640,
        batch=16,
        lr0 = 0.01,
        momentum = 0.937,
        weight_decay = 0.0005,
        optimizer='SGD',
        device=0  # CPU 则改为 'cpu'
    )
# Out:
# New https://pypi.org/project/ultralytics/8.4.23 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.19  Python-3.11.14 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO

if __name__ == '__main__':
    #原本的yolo11nano模型架构
    yolo = YOLO(r'E:\mastercode\6.yolo\runs\segment\train2\weights\last.pt')
    yolo.train(
        data=r'E:\mastercode\6.yolo\ultralytics-main\201_caomei_data.yaml',
        project=r'E:/mastercode/6.yolo/runs/segment',
        epochs=50,
        imgsz=640,
        batch=8,
        lr0 = 0.01,
        momentum = 0.937,
        weight_decay = 0.0005,
        optimizer='SGD',
        device=0  # CPU 则改为 'cpu'
    )
# Out:
# New https://pypi.org/project/ultralytics/8.4.23 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.19  Python-3.11.14 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO

if __name__ == '__main__':
    #增加了注意力机制的模型架构
    yolo = YOLO(r'E:\mastercode\6.yolo\ultralytics-main\ultralytics\cfg\models\11\yolo11-GDA-seg.yaml')
    yolo.train(
        data=r'E:\mastercode\6.yolo\ultralytics-main\201_caomei_data.yaml',
        project=r'E:/mastercode/6.yolo/runs/segment',
        epochs=150,
        imgsz=640,
        batch=8,
        lr0 = 0.01,
        momentum = 0.937,
        weight_decay = 0.0005,
        optimizer='SGD',
        device=0  # CPU 则改为 'cpu'
    )
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.23 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.19  Python-3.11.14 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO

if __name__ == '__main__':
    #增加可变性卷积的模型架构
    yolo = YOLO(r'E:\mastercode\6.yolo\ultralytics-main\ultralytics\cfg\models\11\yolo11-seg-tansconv.yaml')
    yolo.train(
        data=r'E:\mastercode\6.yolo\ultralytics-main\201_caomei_data.yaml',
        project=r'E:/mastercode/6.yolo/runs/segment',
        epochs=150,
        imgsz=640,
        batch=8,
        lr0 = 0.01,
        momentum = 0.937,
        weight_decay = 0.0005,
        optimizer='SGD',
        device=0,  # CPU 则改为 'cpu'
        amp=False
    )
# Out:
# WARNING no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.4.23 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.19  Python-3.11.14 torch-2.5.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
