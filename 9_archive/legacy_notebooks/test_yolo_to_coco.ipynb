# %%
import torch
import torch.nn as nn
import numpy as np
import cv2

# %%
img = cv2.imread(r"E:\mastercode\data\shr_watermelon\images\train\dsc00001.jpg" , cv2.IMREAD_UNCHANGED)

# %%
img.shape # type: ignore
# Out:
# (640, 960, 3)

# %%
import os
import json
import argparse
from pathlib import Path
from PIL import Image  # pip install Pillow

# %%
"""
YOLO TXT → COCO JSON 一键转换脚本
用法：修改下方配置区 → 直接运行 python yolo2coco.py
纯标准库，无需 pip install 任何东西
"""

# ===================== ✏️ 配置区（只改这里） =====================

# 类别名称列表（按 YOLO class_id 顺序填写）
CLASS_NAMES = ["blooming male", "unknown", "closed male", "blooming female", "closed female"]

# YOLO 标注文件夹（里面是 .txt 文件）
LABELS_DIR = "E:\\mastercode\\data\\shr_watermelon\\object_detection\\labels\\val"

# 图片文件夹（里面是图片文件）
IMAGES_DIR = "E:\\mastercode\\data\\shr_watermelon\\object_detection\\images\\val"

# 输出 COCO JSON 文件路径
OUTPUT_JSON = "E:\\mastercode\\data\\shr_watermelon\\object_detection\\images\\val\\annotations.json"

# ================================================================


import os
import json
import subprocess
from pathlib import Path

IMAGE_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".tiff", ".webp"}


# ───────────── 获取图片尺寸（Windows 专用，绝对不报错） ─────────────
def get_image_size(filepath: str):
    """利用 Windows 自带的 PowerShell 获取图片宽高，无需安装任何库"""
    abs_path = os.path.abspath(filepath).replace("'", "''")
    ps_cmd = (
        f"Add-Type -AssemblyName System.Drawing; "
        f"$img = [System.Drawing.Image]::FromFile('{abs_path}'); "
        f"Write-Output ($img.Width.ToString() + ' ' + $img.Height.ToString()); "
        f"$img.Dispose()"
    )
    result = subprocess.run(
        ["powershell", "-NoProfile", "-Command", ps_cmd],
        capture_output=True, text=True, creationflags=0x08000000  # 隐藏黑框
    )
    if result.returncode == 0 and result.stdout.strip():
        w, h = result.stdout.strip().split()
        return int(w), int(h)
    raise ValueError(f"无法获取尺寸: {filepath}")


# ───────────── 转换主逻辑 ─────────────
def yolo_to_coco():
    coco = {
        "images": [],
        "annotations": [],
        "categories": [
            {"id": i, "name": name, "supercategory": "object"}
            for i, name in enumerate(CLASS_NAMES)
        ],
    }

    label_files = sorted(Path(LABELS_DIR).glob("*.txt"))
    if not label_files:
        print(f"❌ 在 {LABELS_DIR} 中没找到 .txt 文件")
        return

    ann_id = 1
    img_id = 1

    for lf in label_files:
        stem = lf.stem

        # 自动匹配图片
        img_path = None
        for p in Path(IMAGES_DIR).iterdir():
            if p.stem == stem and p.suffix.lower() in IMAGE_EXTS:
                img_path = str(p)
                break

        if not img_path:
            print(f"⚠️  找不到图片: {stem}.*  跳过")
            continue

        try:
            img_w, img_h = get_image_size(img_path)
        except Exception as e:
            print(f"⚠️  {e}  跳过")
            continue

        coco["images"].append({
            "id": img_id,
            "file_name": Path(img_path).name,
            "width": img_w,
            "height": img_h,
        })

        for line in lf.read_text(encoding="utf-8").strip().splitlines():
            parts = line.strip().split()
            if len(parts) < 5:
                continue

            cid  = int(parts[0])
            xc   = float(parts[1])
            yc   = float(parts[2])
            bw   = float(parts[3])
            bh   = float(parts[4])

            abs_w = bw * img_w
            abs_h = bh * img_h
            abs_x = xc * img_w - abs_w / 2
            abs_y = yc * img_h - abs_h / 2

            abs_x = max(0.0, abs_x)
            abs_y = max(0.0, abs_y)
            abs_w = min(abs_w, img_w - abs_x)
            abs_h = min(abs_h, img_h - abs_y)

            coco["annotations"].append({
                "id": ann_id,
                "image_id": img_id,
                "category_id": cid,
                "bbox": [round(abs_x, 2), round(abs_y, 2),
                         round(abs_w, 2), round(abs_h, 2)],
                "area": round(abs_w * abs_h, 2),
                "iscrowd": 0,
                "segmentation": [],
            })
            ann_id += 1

        img_id += 1

    # 保存
    os.makedirs(os.path.dirname(OUTPUT_JSON) or ".", exist_ok=True)
    with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
        json.dump(coco, f, ensure_ascii=False, indent=2)

    print(f"✅ 完成！")
    print(f"   图片: {len(coco['images'])} 张")
    print(f"   标注: {len(coco['annotations'])} 个")
    print(f"   输出: {OUTPUT_JSON}")


if __name__ == "__main__":
    yolo_to_coco()
# Out:
# ✅ 完成！
#    图片: 620 张
#    标注: 1486 个
#    输出: E:\mastercode\data\shr_watermelon\object_detection\images\val\annotations.json

# %%
"""
YOLO 分割 TXT → COCO 分割 JSON 一键转换脚本
用法：修改下方配置区 → 直接运行 python yolo2coco_seg.py
"""

# ===================== ✏️ 配置区（只改这里） =====================

# 类别名称列表（按 YOLO class_id 顺序填写）
CLASS_NAMES = ["blooming male", "unknown", "closed male", "blooming female", "closed female"]  # 改成你的类别

# YOLO 分割标注文件夹（里面是 .txt 文件，格式: class x1 y1 x2 y2 ...）
LABELS_DIR = r"E:\mastercode\data\shr_watermelon\segmentation\labels\val"

# 图片文件夹（里面是图片文件）
IMAGES_DIR = r"E:\mastercode\data\shr_watermelon\segmentation\images\val"

# 输出 COCO JSON 文件路径
OUTPUT_JSON = r"E:\mastercode\data\shr_watermelon\segmentation\images\annotations_seg_val.json"

# ================================================================

import os
import json
import subprocess
from pathlib import Path

IMAGE_EXTS = {".jpg", ".jpeg", ".png", ".bmp", ".tiff", ".webp"}


# ───────────── 获取图片尺寸（Windows 专用） ─────────────
def get_image_size(filepath: str):
    abs_path = os.path.abspath(filepath).replace("'", "''")
    ps_cmd = (
        f"Add-Type -AssemblyName System.Drawing; "
        f"$img = [System.Drawing.Image]::FromFile('{abs_path}'); "
        f"Write-Output ($img.Width.ToString() + ' ' + $img.Height.ToString()); "
        f"$img.Dispose()"
    )
    result = subprocess.run(
        ["powershell", "-NoProfile", "-Command", ps_cmd],
        capture_output=True, text=True, creationflags=0x08000000 
    )
    if result.returncode == 0 and result.stdout.strip():
        w, h = result.stdout.strip().split()
        return int(w), int(h)
    raise ValueError("无法获取尺寸")


# ───────────── 数学计算：多边形面积（鞋带公式） ─────────────
def calculate_polygon_area(pts):
    """计算多边形面积，pts 为 [(x1,y1), (x2,y2), ...]"""
    n = len(pts)
    if n < 3:
        return 0.0
    area = 0.0
    for i in range(n):
        j = (i + 1) % n
        area += pts[i][0] * pts[j][1]
        area -= pts[j][0] * pts[i][1]
    return abs(area) / 2.0


# ───────────── 转换主逻辑 ─────────────
def yolo_seg_to_coco():
    coco = {
        "images": [],
        "annotations": [],
        "categories": [
            {"id": i, "name": name, "supercategory": "object"}
            for i, name in enumerate(CLASS_NAMES)
        ],
    }

    label_files = sorted(Path(LABELS_DIR).glob("*.txt"))
    total_files = len(label_files)
    
    if total_files == 0:
        print(f"❌ 在 {LABELS_DIR} 中没找到 .txt 文件")
        return

    ann_id = 1
    img_id = 1
    success_count = 0

    print(f"🚀 开始转换【分割数据】，共发现 {total_files} 个标注文件...\n")

    for idx, lf in enumerate(label_files, 1):
        stem = lf.stem

        # 1. 自动匹配图片
        img_path = None
        for p in Path(IMAGES_DIR).iterdir():
            if p.stem == stem and p.suffix.lower() in IMAGE_EXTS:
                img_path = str(p)
                break

        if not img_path:
            print(f"[{idx}/{total_files}] ⚠️  找不到图片: {stem}.* (跳过)")
            continue

        # 2. 获取图片尺寸
        try:
            img_w, img_h = get_image_size(img_path)
        except Exception:
            print(f"[{idx}/{total_files}] ⚠️  无法读取尺寸: {Path(img_path).name} (跳过)")
            continue

        # 3. 添加图片信息
        coco["images"].append({
            "id": img_id,
            "file_name": Path(img_path).name,
            "width": img_w,
            "height": img_h,
        })

        # 4. 解析分割标注
        current_img_anns = 0
        for line in lf.read_text(encoding="utf-8").strip().splitlines():
            parts = line.strip().split()
            # 至少需要 class_id + 3个点(6个坐标) = 7个元素
            if len(parts) < 7: 
                continue

            cid = int(parts[0])
            coords = [float(c) for c in parts[1:]]
            
            # 坐标必须是成对的 (x, y)
            if len(coords) % 2 != 0:
                continue 

            # 归一化 -> 绝对像素坐标
            seg_flat = []      # COCO 需要的展平格式 [x1, y1, x2, y2...]
            poly_pts = []      # 用于计算面积和 bbox 的元组格式 [(x1,y1), ...]
            
            for i in range(0, len(coords), 2):
                px = coords[i] * img_w
                py = coords[i+1] * img_h
                
                # 防止坐标越界
                px = max(0.0, min(px, float(img_w)))
                py = max(0.0, min(py, float(img_h)))
                
                seg_flat.extend([round(px, 2), round(py, 2)])
                poly_pts.append((px, py))

            # 计算外接矩形 bbox [x_min, y_min, width, height]
            xs = [p[0] for p in poly_pts]
            ys = [p[1] for p in poly_pts]
            x_min = min(xs)
            y_min = min(ys)
            bbox_w = max(xs) - x_min
            bbox_h = max(ys) - y_min

            # 计算多边形真实面积
            area = calculate_polygon_area(poly_pts)

            # 过滤掉面积或宽高为 0 的无效标注
            if area <= 0 or bbox_w <= 0 or bbox_h <= 0:
                continue

            coco["annotations"].append({
                "id": ann_id,
                "image_id": img_id,
                "category_id": cid,
                "segmentation": [seg_flat],  # COCO 格式要求外层套一个列表
                "bbox": [round(x_min, 2), round(y_min, 2), 
                         round(bbox_w, 2), round(bbox_h, 2)],
                "area": round(area, 2),
                "iscrowd": 0
            })
            ann_id += 1
            current_img_anns += 1

        # 5. 打印单张图片处理结果
        print(f"[{idx}/{total_files}] ✅ 搞定: {Path(img_path).name:<40} | 尺寸: {img_w}x{img_h} | 分割实例: {current_img_anns}")
        
        img_id += 1
        success_count += 1

    # 6. 保存 JSON
    os.makedirs(os.path.dirname(OUTPUT_JSON) or ".", exist_ok=True)
    with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
        json.dump(coco, f, ensure_ascii=False, indent=2)

    print(f"\n🎉 全部完成！")
    print(f"   成功处理: {success_count} / {total_files} 张图片")
    print(f"   总分割实例: {len(coco['annotations'])} 个")
    print(f"   输出文件: {OUTPUT_JSON}")


if __name__ == "__main__":
    yolo_seg_to_coco()
# Out:
# 🚀 开始转换【分割数据】，共发现 109 个标注文件...
#
# [1/109] ✅ 搞定: dsc00005.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [2/109] ✅ 搞定: dsc00023.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [3/109] ✅ 搞定: dsc00029.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [4/109] ✅ 搞定: dsc00030.jpg                             | 尺寸: 960x640 | 分割实例: 5
# [5/109] ✅ 搞定: dsc00035.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [6/109] ✅ 搞定: dsc00036.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [7/109] ✅ 搞定: dsc00043.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [8/109] ✅ 搞定: dsc00046.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [9/109] ✅ 搞定: dsc00047.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [10/109] ✅ 搞定: dsc00067.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [11/109] ✅ 搞定: dsc00077.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [12/109] ✅ 搞定: dsc00078.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [13/109] ✅ 搞定: dsc00091.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [14/109] ✅ 搞定: dsc00113.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [15/109] ✅ 搞定: dsc00116.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [16/109] ✅ 搞定: dsc00158.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [17/109] ✅ 搞定: dsc00164.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [18/109] ✅ 搞定: dsc00183.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [19/109] ✅ 搞定: dsc00188.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [20/109] ✅ 搞定: dsc00200.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [21/109] ✅ 搞定: dsc00221.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [22/109] ✅ 搞定: dsc00223.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [23/109] ✅ 搞定: dsc00254.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [24/109] ✅ 搞定: dsc00261.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [25/109] ✅ 搞定: dsc00266.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [26/109] ✅ 搞定: dsc00270.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [27/109] ✅ 搞定: dsc00275.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [28/109] ✅ 搞定: dsc00289.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [29/109] ✅ 搞定: dsc00296.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [30/109] ✅ 搞定: dsc00297.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [31/109] ✅ 搞定: dsc00305.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [32/109] ✅ 搞定: dsc00309.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [33/109] ✅ 搞定: dsc00310.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [34/109] ✅ 搞定: dsc00311.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [35/109] ✅ 搞定: dsc00315.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [36/109] ✅ 搞定: dsc00318.jpg                             | 尺寸: 960x640 | 分割实例: 6
# [37/109] ✅ 搞定: dsc00320.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [38/109] ✅ 搞定: dsc00336.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [39/109] ✅ 搞定: dsc00349.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [40/109] ✅ 搞定: dsc00359.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [41/109] ✅ 搞定: dsc00374.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [42/109] ✅ 搞定: dsc00390.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [43/109] ✅ 搞定: dsc00397.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [44/109] ✅ 搞定: dsc00412.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [45/109] ✅ 搞定: dsc00417.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [46/109] ✅ 搞定: dsc00421.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [47/109] ✅ 搞定: dsc00434.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [48/109] ✅ 搞定: dsc00435.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [49/109] ✅ 搞定: dsc00441.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [50/109] ✅ 搞定: dsc00447.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [51/109] ✅ 搞定: dsc00450.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [52/109] ✅ 搞定: dsc09412.jpg                             | 尺寸: 960x640 | 分割实例: 8
# [53/109] ✅ 搞定: dsc09413.jpg                             | 尺寸: 960x640 | 分割实例: 8
# [54/109] ✅ 搞定: dsc09415.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [55/109] ✅ 搞定: dsc09416.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [56/109] ✅ 搞定: dsc09422.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [57/109] ✅ 搞定: dsc09442.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [58/109] ✅ 搞定: dsc09456.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [59/109] ✅ 搞定: dsc09462.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [60/109] ✅ 搞定: dsc09473.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [61/109] ✅ 搞定: dsc09487.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [62/109] ✅ 搞定: dsc09488.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [63/109] ✅ 搞定: dsc09501.jpg                             | 尺寸: 960x640 | 分割实例: 10
# [64/109] ✅ 搞定: dsc09517.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [65/109] ✅ 搞定: dsc09522.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [66/109] ✅ 搞定: dsc09523.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [67/109] ✅ 搞定: dsc09539.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [68/109] ✅ 搞定: dsc09562.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [69/109] ✅ 搞定: dsc09573.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [70/109] ✅ 搞定: dsc09585.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [71/109] ✅ 搞定: dsc09586.jpg                             | 尺寸: 960x640 | 分割实例: 8
# [72/109] ✅ 搞定: dsc09597.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [73/109] ✅ 搞定: dsc09600.jpg                             | 尺寸: 960x640 | 分割实例: 5
# [74/109] ✅ 搞定: dsc09622.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [75/109] ✅ 搞定: dsc09623.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [76/109] ✅ 搞定: dsc09641.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [77/109] ✅ 搞定: dsc09653.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [78/109] ✅ 搞定: dsc09655.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [79/109] ✅ 搞定: dsc09662.jpg                             | 尺寸: 960x640 | 分割实例: 5
# [80/109] ✅ 搞定: dsc09676.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [81/109] ✅ 搞定: dsc09687.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [82/109] ✅ 搞定: dsc09700.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [83/109] ✅ 搞定: dsc09703.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [84/109] ✅ 搞定: dsc09783.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [85/109] ✅ 搞定: dsc09784.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [86/109] ✅ 搞定: dsc09805.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [87/109] ✅ 搞定: dsc09811.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [88/109] ✅ 搞定: dsc09817.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [89/109] ✅ 搞定: dsc09829.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [90/109] ✅ 搞定: dsc09830.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [91/109] ✅ 搞定: dsc09838.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [92/109] ✅ 搞定: dsc09841.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [93/109] ✅ 搞定: dsc09866.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [94/109] ✅ 搞定: dsc09874.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [95/109] ✅ 搞定: dsc09877.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [96/109] ✅ 搞定: dsc09887.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [97/109] ✅ 搞定: dsc09893.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [98/109] ✅ 搞定: dsc09895.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [99/109] ✅ 搞定: dsc09901.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [100/109] ✅ 搞定: dsc09919.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [101/109] ✅ 搞定: dsc09923.jpg                             | 尺寸: 960x640 | 分割实例: 5
# [102/109] ✅ 搞定: dsc09928.jpg                             | 尺寸: 960x640 | 分割实例: 3
# [103/109] ✅ 搞定: dsc09937.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [104/109] ✅ 搞定: dsc09946.jpg                             | 尺寸: 960x640 | 分割实例: 2
# [105/109] ✅ 搞定: dsc09951.jpg                             | 尺寸: 960x640 | 分割实例: 4
# [106/109] ✅ 搞定: dsc09955.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [107/109] ✅ 搞定: dsc09976.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [108/109] ✅ 搞定: dsc09991.jpg                             | 尺寸: 960x640 | 分割实例: 1
# [109/109] ✅ 搞定: dsc09998.jpg                             | 尺寸: 960x640 | 分割实例: 1
#
# 🎉 全部完成！
#    成功处理: 109 / 109 张图片
#    总分割实例: 244 个
#    输出文件: E:\mastercode\data\shr_watermelon\segmentation\images\annotations_seg_val.json
